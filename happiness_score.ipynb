# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"Downloads/happiness_score_dataset.csv")

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
# Out:
# (158, 12)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
df.tail(4)
# Out:
#      Country                           Region  Happiness Rank  \
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# ...

# %%
df.head(2)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201

# %%
df.sample(6)
# Out:
#         Country                      Region  Happiness Rank  Happiness Score  \
# 78       Bhutan               Southern Asia              79            5.253
# 105  Tajikistan  Central and Eastern Europe             106            4.786
# 53   Kazakhstan  Central and Eastern Europe              54            5.855
# 68       Kosovo  Central and Eastern Europe              69            5.589
# 2       Denmark              Western Europe               3            7.527
# 86       Serbia  Central and Eastern Europe              87            5.123
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 78          0.03225                   0.77042  1.10395
# 105         0.03198                   0.39047  0.85563
# 53          0.04114                   1.12254  1.12241
# 68          0.05018                   0.80148  0.81198
# 2           0.03328                   1.32548  1.36058
# 86          0.04864                   0.92053  1.00964
#
# ...

# %%
df.sample()
# Out:
#          Country                      Region  Happiness Rank  Happiness Score  \
# 69  Turkmenistan  Central and Eastern Europe              70            5.548
#
#     Standard Error  Economy (GDP per Capita)   Family  \
# 69         0.04175                   0.95847  1.22668
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 69                   0.53886   0.4761                        0.30844
#
#     Generosity  Dystopia Residual
# 69     0.16979            1.86984

# %%
df.sample(1)
# Out:
#       Country                      Region  Happiness Rank  Happiness Score  \
# 55  Lithuania  Central and Eastern Europe              56            5.833
#
#     Standard Error  Economy (GDP per Capita)   Family  \
# 55         0.03843                   1.14723  1.25745
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 55                   0.73128  0.21342                        0.01031
#
#     Generosity  Dystopia Residual
# 55     0.02641            2.44649

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df['Country'].count()
# Out:
# 158

# %%
df['Country'].min()
# Out:
# 'Afghanistan'

# %%
df.iloc[9]
# Out:
# Country                                          Australia
# Region                           Australia and New Zealand
# Happiness Rank                                          10
# Happiness Score                                      7.284
# Standard Error                                     0.04083
# Economy (GDP per Capita)                           1.33358
# Family                                             1.30923
# Health (Life Expectancy)                           0.93156
# Freedom                                            0.65124
# Trust (Government Corruption)                      0.35637
# Generosity                                         0.43562
# Dystopia Residual                                  2.26646
# Name: 9, dtype: object

# %%
df.iloc[1:15]
# Out:
#           Country                           Region  Happiness Rank  \
# 1         Iceland                   Western Europe               2
# 2         Denmark                   Western Europe               3
# 3          Norway                   Western Europe               4
# 4          Canada                    North America               5
# 5         Finland                   Western Europe               6
# 6     Netherlands                   Western Europe               7
# 7          Sweden                   Western Europe               8
# 8     New Zealand        Australia and New Zealand               9
# 9       Australia        Australia and New Zealand              10
# 10         Israel  Middle East and Northern Africa              11
# 11     Costa Rica      Latin America and Caribbean              12
# 12        Austria                   Western Europe              13
# 13         Mexico      Latin America and Caribbean              14
# ...

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df.describe(include='all')
# Out:
#             Country              Region  Happiness Rank  Happiness Score  \
# count           158                 158      158.000000       158.000000
# unique          158                  10             NaN              NaN
# top     Switzerland  Sub-Saharan Africa             NaN              NaN
# freq              1                  40             NaN              NaN
# mean            NaN                 NaN       79.493671         5.375734
# std             NaN                 NaN       45.754363         1.145010
# min             NaN                 NaN        1.000000         2.839000
# 25%             NaN                 NaN       40.250000         4.526000
# 50%             NaN                 NaN       79.500000         5.232500
# 75%             NaN                 NaN      118.750000         6.243750
# max             NaN                 NaN      158.000000         7.587000
#
#         Standard Error  Economy (GDP per Capita)      Family  \
# ...

# %%
df.loc[:,'Region'].count()
# Out:
# 158

# %%
df.loc[:,'Region']
# Out:
# 0                       Western Europe
# 1                       Western Europe
# 2                       Western Europe
# 3                       Western Europe
# 4                        North America
#                     ...
# 153                 Sub-Saharan Africa
# 154                 Sub-Saharan Africa
# 155    Middle East and Northern Africa
# 156                 Sub-Saharan Africa
# 157                 Sub-Saharan Africa
# Name: Region, Length: 158, dtype: object

# %%
df.loc[1:55,'Family']
# Out:
# 1     1.40223
# 2     1.36058
# 3     1.33095
# 4     1.32261
# 5     1.31826
# 6     1.28017
# 7     1.28907
# 8     1.31967
# 9     1.30923
# 10    1.22393
# 11    1.23788
# 12    1.29704
# 13    0.91451
# 14    1.24711
# 15    1.23287
# 16    1.21963
# 17    1.36948
# 18    1.28566
# 19    1.12575
# 20    1.28548
# 21    1.08182
# 22    1.25596
# 23    1.02000
# 24    1.19850
# 25    1.29937
# 26    1.12447
# 27    1.07860
# 28    1.26038
# 29    1.24823
# 30    1.20643
# 31    1.20890
# 32    1.24018
# 33    1.26504
# 34    1.08393
# 35    1.31379
# 36    1.30203
# 37    1.07617
# 38    1.16594
# 39    0.97200
# 40    1.18354
# 41    1.02507
# 42    1.04356
# 43    1.34043
# 44    1.26999
# 45    1.25712
# 46    0.95774
# 47    0.99903
# 48    1.21624
# 49    1.19777
# 50    0.97841
# 51    1.01528
# 52    1.30477
# 53    1.12241
# 54    1.27385
# 55    1.25745
# Name: Family, dtype: float64

# %%
df.loc[:,['Freedom','Generosity']]
# Out:
#      Freedom  Generosity
# 0    0.66557     0.29678
# 1    0.62877     0.43630
# 2    0.64938     0.34139
# 3    0.66973     0.34699
# 4    0.63297     0.45811
# ..       ...         ...
# 153  0.59201     0.22628
# 154  0.48450     0.18260
# 155  0.15684     0.47179
# 156  0.11850     0.19727
# 157  0.36453     0.16681
#
# [158 rows x 2 columns]

# %%
df.loc[1:10,['Region']]
# Out:
#                              Region
# 1                    Western Europe
# 2                    Western Europe
# 3                    Western Europe
# 4                     North America
# 5                    Western Europe
# 6                    Western Europe
# 7                    Western Europe
# 8         Australia and New Zealand
# 9         Australia and New Zealand
# 10  Middle East and Northern Africa

# %%
df.rename(columns={'Freedom':'Independence'},inplace=True)

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df['Place'][3]='Sweden'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Place'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[280], line 1
# ----> 1 df['Place'][3]='Sweden'
#
# ...

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Independence                     0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.isnull()
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      False   False           False            False           False
# 1      False   False           False            False           False
# 2      False   False           False            False           False
# 3      False   False           False            False           False
# 4      False   False           False            False           False
# ..       ...     ...             ...              ...             ...
# 153    False   False           False            False           False
# 154    False   False           False            False           False
# 155    False   False           False            False           False
# 156    False   False           False            False           False
# 157    False   False           False            False           False
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Independence  \
# ...

# %%
df['Independence'][9]=['1']

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df['Happiness Rank'][3]='1'

# %%
df
# Out:
#          Country                           Region Happiness Rank  \
# 0    Switzerland                   Western Europe              1
# 1        Iceland                   Western Europe              2
# 2        Denmark                   Western Europe              3
# 3         Norway                   Western Europe              1
# 4         Canada                    North America              5
# ..           ...                              ...            ...
# 153       Rwanda               Sub-Saharan Africa            154
# 154        Benin               Sub-Saharan Africa            155
# 155        Syria  Middle East and Northern Africa            156
# 156      Burundi               Sub-Saharan Africa            157
# 157         Togo               Sub-Saharan Africa            158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.drop('Family',axis=1,inplace=True)

# %%
df
# Out:
#          Country                           Region Happiness Rank  \
# 0    Switzerland                   Western Europe              1
# 1        Iceland                   Western Europe              2
# 2        Denmark                   Western Europe              3
# 3         Norway                   Western Europe              1
# 4         Canada                    North America              5
# ..           ...                              ...            ...
# 153       Rwanda               Sub-Saharan Africa            154
# 154        Benin               Sub-Saharan Africa            155
# 155        Syria  Middle East and Northern Africa            156
# 156      Burundi               Sub-Saharan Africa            157
# 157         Togo               Sub-Saharan Africa            158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)  \
# 0              7.587         0.03411                   1.39651
# ...

# %%
df.drop('Region',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[312], line 1
# ----> 1 df.drop('Region',axis=1,inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df
# Out:
#          Country Happiness Rank  Happiness Score  Standard Error  \
# 0    Switzerland              1            7.587         0.03411
# 1        Iceland              2            7.561         0.04884
# 2        Denmark              3            7.527         0.03328
# 3         Norway              1            7.522         0.03880
# 4         Canada              5            7.427         0.03553
# ..           ...            ...              ...             ...
# 153       Rwanda            154            3.465         0.03464
# 154        Benin            155            3.340         0.03656
# 155        Syria            156            3.006         0.05015
# 156      Burundi            157            2.905         0.08658
# 157         Togo            158            2.839         0.06727
#
#      Economy (GDP per Capita)  Health (Life Expectancy) Independence  \
# 0                     1.39651                   0.94143      0.66557
# ...

# %%
df=df.iloc[:10,1:5]

# %%
df
# Out:
#   Happiness Rank  Happiness Score  Standard Error  Economy (GDP per Capita)
# 0              1            7.587         0.03411                   1.39651
# 1              2            7.561         0.04884                   1.30232
# 2              3            7.527         0.03328                   1.32548
# 3              1            7.522         0.03880                   1.45900
# 4              5            7.427         0.03553                   1.32629
# 5              6            7.406         0.03140                   1.29025
# 6              7            7.378         0.02799                   1.32944
# 7              8            7.364         0.03157                   1.33171
# 8              9            7.286         0.03371                   1.25018
# 9             10            7.284         0.04083                   1.33358

# %%
df
# Out:
#   Happiness Rank  Happiness Score  Standard Error  Economy (GDP per Capita)
# 0              1            7.587         0.03411                   1.39651
# 1              2            7.561         0.04884                   1.30232
# 2              3            7.527         0.03328                   1.32548
# 3              1            7.522         0.03880                   1.45900
# 4              5            7.427         0.03553                   1.32629
# 5              6            7.406         0.03140                   1.29025
# 6              7            7.378         0.02799                   1.32944
# 7              8            7.364         0.03157                   1.33171
# 8              9            7.286         0.03371                   1.25018
# 9             10            7.284         0.04083                   1.33358

# %%
df[df['Happiness Rank']=='1']
# Out:
#   Happiness Rank  Happiness Score  Standard Error  Economy (GDP per Capita)
# 3              1            7.522          0.0388                     1.459

# %%
df[df['Generosity'].isnull()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Generosity'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[324], line 1
# ----> 1 df[df['Generosity'].isnull()]
#
# ...

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df['Region'].isna().sum()
# Out:
# 0

# %%
df.dropna(axis=0,inplace=True)

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# JOIN PANDAS

# %%
dict1={'s.no':[1,2,3],'name':['anu','banu','charu'],'salary':[100,200,300]}

# %%
dict2={'s.no':[4,5,6],'name':['sri','ammu','arun'],'salary':[100,200,300]}

# %%
df1=pd.DataFrame(dict1)

# %%
df2=pd.DataFrame(dict2)

# %%
df1
# Out:
#    s.no   name  salary
# 0     1    anu     100
# 1     2   banu     200
# 2     3  charu     300

# %%
df2
# Out:
#    s.no  name  salary
# 0     4   sri     100
# 1     5  ammu     200
# 2     6  arun     300
